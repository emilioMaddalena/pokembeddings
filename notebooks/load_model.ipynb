# %%
import tensorflow as tf
from model import Word2Vec

# Load the model from the directory
model_save_path = "./saved_model"
word2vec = tf.keras.models.load_model(model_save_path, custom_objects={"Word2Vec": Word2Vec})

# Verify that the loaded model is the same as the original model
print(word2vec.summary())
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RestoredOptimizer` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RestoredOptimizer`.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Word2Vec vocabulary size: 1471
# ...

# %%
# Example usage
word2vec.get_word_embedding("pikachu")
# Out:
# array([ 1.8420496, -1.453428 , -1.3014513], dtype=float32)

# %%
# Example usage
word2vec.compute_similarity("bulbasaur", "seed")
# Out:
# 8.493479

# %%
# Example usage
word2vec.compute_similarity("bulbasaur", "fire")
# Out:
# 10.071845

# %%
word2vec.vocabulary
# Out:
# {'programming',
#  'butterfrees',
#  'tail',
#  'rhyhorns',
#  'apparently',
#  'toxic',
#  'males',
#  'wild',
#  'hands',
#  'technology',
#  'caves',
#  'rains',
#  'eggs',
#  'cold',
#  'magneton',
#  'laugh',
#  'pikachu',
#  'foul',
#  'long',
#  'zubath',
#  'stagbeetle',
#  'change',
#  'easily',
#  'rhydons',
#  'magnetons',
#  'inflate',
#  'sharper',
#  'always',
#  'communicates',
#  'sword',
#  'stinger',
#  'sees',
#  'organ',
#  'carrying',
#  'in',
#  'impressive',
#  'psi',
#  'glow',
#  'rhythm',
#  '100',
#  'shatter',
#  'gets',
#  'nidoqueens',
#  'huge',
#  'unleashing',
#  '40',
#  'viewed',
#  'bat',
#  'check',
#  'algae',
#  '1700',
#  'been',
#  'sea',
#  'dugtrio',
#  'stick',
#  'begin',
#  'clefable',
#  'shallow',
#  'hab',
#  'backs',
#  'reconst',
#  'persian',
#  'palms',
#  'danger',
#  'ghost',
#  'jabs',
#  'weedles',
#  'heads',
#  'near',
#  'grows',
#  'many',
#  'timid',
#  'pidgeot',
#  'tongue',
#  'behind',
#  'swimmer',
#  'sticky',
# ...
